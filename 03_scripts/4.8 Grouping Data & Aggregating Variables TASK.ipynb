# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Importing Data

# %%
# Creating a reusable path to my data

path = r'C:\Users\Vaiva\Documents\CareerFoundry\Achievement 4 07-2023 Instacart Basket Analysis'

# %%
# Importing orders_products_merged.pkl

df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_new_var.pkl'))

# %%
df.shape
# Out:
# (32404859, 18)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    user_id  order_id  order_number  order_day_of_week  order_hour_of_day  \
# 0      138   3139998            28                  6                 11
# 1      138   1977647            30                  6                 17
# 2      709    389851             2                  0                 21
# 3      764    652770             1                  3                 13
# 4      764   1813452             3                  4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered   ind  \
# ...

# %% [markdown]
# ## 3. Task

# %% [markdown]
# ### Step 2

# %% [markdown]
# #### Find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe.

# %%
# Group data by department_id

df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Step 3

# %% [markdown]
# #### How do the results for the entire dataframe differ from those of the subset?

# %% [markdown]
# The means for different departments differ slightly, however it doesn't seem to have a pattern, some means are higher, some are lower if comparing a subset with the full dataframe.

# %% [markdown]
# ### Step 4

# %% [markdown]
# #### Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %% [markdown]
# Criteria for the flag:
#
# 1. If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# 2. If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# 3. If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
# Creating a new column max_order

df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking if the column was created

df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    user_id  order_id  order_number  order_day_of_week  order_hour_of_day  \
# 0      138   3139998            28                  6                 11
# 1      138   1977647            30                  6                 17
# 2      709    389851             2                  0                 21
# 3      764    652770             1                  3                 13
# 4      764   1813452             3                  4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered   ind  \
# ...

# %%
# Creating a loyalty flag in a new column

df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking if the column was created

df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    user_id  order_id  order_number  order_day_of_week  order_hour_of_day  ...  \
# 0      138   3139998            28                  6                 11  ...
# 1      138   1977647            30                  6                 17  ...
# 2      709    389851             2                  0                 21  ...
# 3      764    652770             1                  3                 13  ...
# 4      764   1813452             3                  4                 17  ...
#
# ...

# %%
# Checking counts

df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### Step 5

# %% [markdown]
# ####  Is there a difference between the spending habits of the three types of customers? Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Grouping by loyalty flag/category and printing average, min and max of prices.

df.groupby('loyalty_flag').agg({'prices': ['mean', 'median', 'min', 'max']})
# Out:
#                      prices
#                        mean median  min      max
# loyalty_flag
# Loyal customer    10.386336    7.4  1.0  99999.0
# New customer      13.294670    7.4  1.0  99999.0
# Regular customer  12.495717    7.4  1.0  99999.0

# %%
# Creating a subset of products with price 99999

df_99999 = df[df['prices'] == 99999]

# %%
# Checking counts of products with price 99999

df_99999['product_name'].value_counts(dropna = True)
# Out:
# 2 % Reduced Fat  Milk    698
# Name: product_name, dtype: int64

# %%
# Replacing 99999 price with a price of $6.4 from Instacart website for 2 % Reduced Fat Milk

df['prices'] = df['prices'].replace(99999, 6.4)

# %%
# Checking descriptive statistics for the prices column without the 99999 value

df['prices'].describe().astype(int)
# Out:
# count    32404859
# mean            9
# std           174
# min             1
# 25%             4
# 50%             7
# 75%            11
# max         14900
# Name: prices, dtype: int32

# %%
# Creating a subset of products with price 14900

df_14900 = df[df['prices'] == 14900]

# %%
# Checking counts of products with price 14900

df_14900['product_name'].value_counts(dropna = True)
# Out:
# Lowfat 2% Milkfat Cottage Cheese    4429
# Name: product_name, dtype: int64

# %%
# Replacing 14900 price with a price of $3.3 from Instacart website for Lowfat 2% Milkfat Cottage Cheese

df['prices'] = df['prices'].replace(14900, 3.3)

# %%
# Rechecking the basic descriptive statistics of 'prices' column without 14900 value

df['prices'].describe().astype(int)
# Out:
# count    32404859
# mean            7
# std             4
# min             1
# 25%             4
# 50%             7
# 75%            11
# max            25
# Name: prices, dtype: int32

# %%
# Reruning the loyalty flag/category grouping with descriptive statistics of price (average, min and max of prices).

df.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.773021  1.0  25.0
# New customer      7.800478  1.0  25.0
# Regular customer  7.797592  1.0  25.0

# %% [markdown]
# #### Comment:
#
# After cleaning up the incorrect prices, it seems that there is not a significant differece among the prices of products purchased by different customer groups. New customers seem to have a slightly higher average. To confirm if the difference is insignificant, I would run an ANOVA test for these 3 variables.

# %% [markdown]
# ### Step 6

# %% [markdown]
# #### Create a spending flag for each user based on the average price across all their orders using the following criteria:
# 1. If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# 2. If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Creating a new column average_spend

df['average_spend'] = df.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Checking if the column was created

df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    user_id  order_id  order_number  order_day_of_week  order_hour_of_day  ...  \
# 0      138   3139998            28                  6                 11  ...
# 1      138   1977647            30                  6                 17  ...
# 2      709    389851             2                  0                 21  ...
# 3      764    652770             1                  3                 13  ...
# 4      764   1813452             3                  4                 17  ...
#
# ...

# %%
# Creating a spending flag in a new column

df.loc[df['average_spend'] >= 10, 'spending_flag'] = 'High Spender'
df.loc[df['average_spend'] < 10, 'spending_flag'] = 'Low Spender'

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    user_id  order_id  order_number  order_day_of_week  order_hour_of_day  ...  \
# 0      138   3139998            28                  6                 11  ...
# 1      138   1977647            30                  6                 17  ...
# 2      709    389851             2                  0                 21  ...
# 3      764    652770             1                  3                 13  ...
# 4      764   1813452             3                  4                 17  ...
#
# ...

# %%
# Checking counts

df['spending_flag'].value_counts(dropna = False)
# Out:
# Low Spender     32285165
# High Spender      119694
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### Step 7

# %% [markdown]
# #### In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# 1. If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# 2. If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# 3. If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Creating a new column days_since_prior_order_median

df['days_since_prior_order_median'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Checking if the column was created

df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    user_id  order_id  order_number  order_day_of_week  order_hour_of_day  ...  \
# 0      138   3139998            28                  6                 11  ...
# 1      138   1977647            30                  6                 17  ...
# 2      709    389851             2                  0                 21  ...
# 3      764    652770             1                  3                 13  ...
# 4      764   1813452             3                  4                 17  ...
#
# ...

# %%
# Creating a frequency flag in a new column

df.loc[df['days_since_prior_order_median'] > 20, 'frequency_flag'] = 'Non-frequent customer'
df.loc[(df['days_since_prior_order_median'] <= 20) & (df['days_since_prior_order_median'] > 10), 'frequency_flag'] = 'Regular customer'
df.loc[df['days_since_prior_order_median'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Checking if the columns was created

df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    user_id  order_id  order_number  order_day_of_week  order_hour_of_day  ...  \
# 0      138   3139998            28                  6                 11  ...
# 1      138   1977647            30                  6                 17  ...
# 2      709    389851             2                  0                 21  ...
# 3      764    652770             1                  3                 13  ...
# 4      764   1813452             3                  4                 17  ...
#
# ...

# %%
# Checking counts of frequency_flag column

df['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %% [markdown]
# #### Comment:
# According to the data dictionary, NA values mean that it is the first order of the person. With this data, we can't say which type of customer the person will become, therefore it's best to leave these 5 values as they are until there is more data about these people.

# %% [markdown]
# ## 4. Exporting Dataframe

# %%
# Exporting orders_products_flagged.pkl

df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_flagged.pkl'))
